# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
viva=pd.read_csv('C:/Users/acer/Downloads/Compressed/logistic regression/Case study/Case 2/viva_credit.csv')

# %%
viva.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
viva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null float64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null float64
# BILL_AMT2                     30000 non-null float64
# BILL_AMT3                     30000 non-null float64
# BILL_AMT4                     30000 non-null float64
# ...

# %%
viva.describe(include='all')
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
viva.drop('ID',axis=1,inplace=True)

# %%
viva.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0    20000.0    2          2         1   24      2      2     -1     -1
# 1   120000.0    2          2         2   26     -1      2      0      0
# 2    90000.0    2          2         2   34      0      0      0      0
# 3    50000.0    2          2         1   37      0      0      0      0
# 4    50000.0    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
viva.shape
# Out:
# (30000, 24)

# %%
viva.select_dtypes(include=[np.number]).columns.tolist()
# Out:
# ['LIMIT_BAL',
#  'SEX',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'default.payment.next.month']

# %%
sns.boxplot(viva['LIMIT_BAL'])

# %%
viva[viva['LIMIT_BAL']>790000]
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 2197   1000000.0    2          1         1   47      0      0      0     -1
# 14919   800000.0    1          2         1   53     -1     -1     -1      0
# 18006   800000.0    1          1         2   46     -2     -2     -2     -1
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 2197       0  ...   891586.0   927171.0   961664.0   50784.0   50723.0
# 14919      0  ...    40814.0    12590.0     9339.0   11145.0   64657.0
# 18006     -1  ...     6193.0     1957.0     3175.0    4644.0    3832.0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# 2197   896040.0   50000.0   50000.0   50256.0                           0
# 14919     131.0     247.0    9366.0   63482.0                           0
# 18006    6219.0    1961.0    3183.0   27201.0                           0
#
# [3 rows x 24 columns]

# %%
viva.drop(viva[viva.index==2197].index,inplace=True)

# %%
viva.drop(viva[viva.index==14919].index,inplace=True)

# %%
viva.drop(viva[viva.index==18006].index,inplace=True)

# %%
viva[viva['LIMIT_BAL']>750000]
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 21375   760000.0    1          3         1   54      0      0      0      0
# 24320   780000.0    1          1         1   48      0      0      0      0
# 28715   780000.0    2          2         2   41     -2     -2     -2     -2
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 21375      0  ...   469931.0   474421.0   480598.0   20011.0   19500.0
# 24320      0  ...   195124.0   184872.0   191090.0   10000.0   15004.0
# 28715     -2  ...    21482.0    72628.0   182792.0   62819.0   39558.0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# 21375   19019.0   18003.0   20000.0   22000.0                           0
# 24320   10000.0    8000.0   10028.0    7003.0                           0
# 28715   22204.0   82097.0  184322.0   25695.0                           0
#
# [3 rows x 24 columns]

# %%
viva.drop(viva[viva.index==21375].index,inplace=True)
viva.drop(viva[viva.index==24320].index,inplace=True)
viva.drop(viva[viva.index==28715].index,inplace=True)

# %%
sns.boxplot(viva['BILL_AMT1'])

# %%
viva[viva['BILL_AMT1']>600000]
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 6912    590000.0    1          1         1   63      0      0      0     -1
# 10780   330000.0    1          1         2   44      0      0      0      0
# 11557   480000.0    2          1         2   33      0      0      0      0
# 14553   450000.0    1          2         2   30      0      0      0      0
# 26227   610000.0    2          1         2   38      0      0      0      0
# 26547   520000.0    2          3         1   54      0      0      0      0
# 27498   500000.0    1          3         1   55      2      0      0      0
# 27557   730000.0    1          3         1   56      0      0      0      0
# 28142   430000.0    2          5         2   44      0      0      0      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 6912       0  ...   324522.0   358774.0   369685.0   28000.0   61115.0
# ...

# %%
viva.drop(viva[viva.index==6912].index,inplace=True)

# %%
viva.drop(viva[viva.index==10780].index,inplace=True)
viva.drop(viva[viva.index==11557].index,inplace=True)
viva.drop(viva[viva.index==14553].index,inplace=True)
viva.drop(viva[viva.index==26227].index,inplace=True)
viva.drop(viva[viva.index==27498].index,inplace=True)
viva.drop(viva[viva.index==26547].index,inplace=True)
viva.drop(viva[viva.index==27557].index,inplace=True)
viva.drop(viva[viva.index==28142].index,inplace=True)

# %%
viva.select_dtypes(include=[np.number]).columns.tolist()
# Out:
# ['LIMIT_BAL',
#  'SEX',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'default.payment.next.month']

# %%
x_var=['LIMIT_BAL',
 'SEX',
 'EDUCATION',
 'MARRIAGE',
 'AGE',
 'PAY_0',
 'PAY_2',
 'PAY_3',
 'PAY_4',
 'PAY_5',
 'PAY_6',
 'BILL_AMT1',
 'BILL_AMT2',
 'BILL_AMT3',
 'BILL_AMT4',
 'BILL_AMT5',
 'BILL_AMT6',
 'PAY_AMT1',
 'PAY_AMT2',
 'PAY_AMT3',
 'PAY_AMT4',
 'PAY_AMT5',
 'PAY_AMT6',]

# %%
x=viva[x_var]

# %%
y=viva['default.payment.next.month']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=44)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr1=LogisticRegression()

# %%
lr1.fit(x_train,y_train)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=lr1.predict(x_test)

# %%
from sklearn.metrics import recall_score,precision_score,roc_auc_score,f1_score,accuracy_score

# %%
print(y_pred.shape)
print(y_test.shape)
# Out:
# (8996,)
# (8996,)

# %%
roc_auc=roc_auc_score(y_test,y_pred)
f1=f1_score(y_test,y_pred)
accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\acer\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print('roc_auc is ',roc_auc)
print('accuracy is ',accuracy)
print('precision is',precision)
print('recall is ',recall)
print('f1 score is ',f1)
# Out:
# roc_auc is  0.5
# accuracy is  0.7774566473988439
# precision is 0.0
# recall is  0.0
# f1 score is  0.0
